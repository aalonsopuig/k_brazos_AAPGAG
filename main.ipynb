# %% [markdown]
# # Estudio comparativo de algoritmos en un problema de k-armed bandit

# %%
from IPython.display import display, HTML
import os

# Verificar si se está ejecutando en Google Colab
IN_COLAB = "google.colab" in str(get_ipython())

# Instalar dependencias si no están presentes
def install_dependencies():
    if not os.path.exists("requirements.txt"):
        print("El archivo requirements.txt no se encuentra en la raíz del repositorio.")
    else:
        print("Instalando dependencias...")
        # !pip install -r requirements.txt

if IN_COLAB:
    install_dependencies()

# Lista de notebooks con enlaces a Colab
notebooks = [
    ("Ascenso por Gradiente", "estudio_ascenso_gradiente.ipynb"),
    ("Métodos Bayesianos", "estudio_bayesianos.ipynb"),
    ("Epsilon-Greedy", "estudio_epsilon_greedy.ipynb"),
    ("UCB", "estudio_UCB.ipynb")
]

# Generar botones de Open in Colab
def generate_colab_buttons():
    repo_url = "https://colab.research.google.com/github/tu_usuario/tu_repositorio/blob/main/"
    html = """
    <h2>Ejecutar Notebooks</h2>
    <p>Selecciona un notebook para ejecutarlo en Google Colab:</p>
    """
    for name, file in notebooks:
        link = f"{repo_url}{file}"
        html += f'<p><a href="{link}" target="_parent">\n'
        html += f'<img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/> {name}</a></p>'
    display(HTML(html))

# Mostrar los botones
generate_colab_buttons()
# Out:
#     <h2>Ejecutar Notebooks</h2>
#     <p>Selecciona un notebook para ejecutarlo en Google Colab:</p>
#     <p><a href="https://colab.research.google.com/github/tu_usuario/tu_repositorio/blob/main/estudio_ascenso_gradiente.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/> Ascenso por Gradiente</a></p><p><a href="https://colab.research.google.com/github/tu_usuario/tu_repositorio/blob/main/estudio_bayesianos.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/> Métodos Bayesianos</a></p><p><a href="https://colab.research.google.com/github/tu_usuario/tu_repositorio/blob/main/estudio_epsilon_greedy.ipynb" target="_parent">
# <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/> Epsilon-Greedy</a></p><p><a href="https://colab.research.google.com/github/tu_usuario/tu_repositorio/blob/main/estudio_UCB.ipynb" target="_parent">
# ...
